# %% [markdown]
# create an iteratior from a list of your name containing first five whole no and its first two elements using next().

# %%
keshav=[1,2,3,4,5]
iterator = iter(keshav)
print(next(iterator))
print(next(iterator))
# Out:
# 1
# 2

# %%
print(next(iterator))
# Out:
# 3

# %% [markdown]
# Convert a string into an iterator and print each character using next().

# %%
text="hello"
int_iter=iter(text)

# %%
print(next(int_iter))
# Out:
# h

# %% [markdown]
# By using for loop

# %%
data = [1,2,3,4,5,6]
iteration = iter(data)

for item in iterator:
  print(item)
# Out:
# 4
# 5

# %% [markdown]
# How to you use a for loop to iterate over an iterator

# %%
letters = iter(["a", "b", "c"])

for letter in letters:
    print(letter)
# Out:
# a
# b
# c

# %% [markdown]
# How do you use iter() and next() to iterate through a range of numbers?

# %%
range_iter = iter(range(5))

print(next(range_iter))
print(next(range_iter))
print(next(range_iter))
# Out:
# 0
# 1
# 2

# %% [markdown]
# Manually iterate through a tuple using an iterator and a while loop.

# %%
fruits = ("apple", "banana", "cherry")
fruit_iter = iter(fruits)

while True:
    try:
        print(next(fruit_iter))
    except StopIteration:
        break
# Out:
# apple
# banana
# cherry
